# %% [markdown]
# # ![Imgur](https://i.imgur.com/5pXzCIu.png)
#
# # **DATA SCIENCE VA SUN'IY INTELLEKT PRAKTIKUM**
#
# ## Ma'lumotlar tahlili. Pandas kutubxonasi.
#
# # **AMALIYOT**
# ## 3.1 Series va Index

# %% [markdown]
# ### **1-mashq**. `Pandas` kutubxonasini `pd`, `numpy` kutubxonasini `np` deb chaqirib oling

# %%
# Javobni shuyerga yozing
import pandas as pd
import numpy as np

# %%
#@title To'g'ri javob
import pandas as pd
import numpy as np

# %% [markdown]
# ### **2-mashq.** O'zbekiston Respublikasi viloyatlaridan iborat bir o'lchamli Series obyektini yarating

# %%
# Javobni shu yerga yozing
regions = ['Fargʻona','Toshkent','Samarqand','Buxoro','Surxondaryo',
 'Qashqadaryo','Xorazm','Namangan','Andijon','Jizzax',
 'Sirdaryo','Navoiy',"Qoraqalpog'iston Respublikasi"]
obj1 = pd.Series(regions)
print(obj1)
# Out:
# 0                          Fargʻona
# 1                          Toshkent
# 2                         Samarqand
# 3                            Buxoro
# 4                       Surxondaryo
# 5                       Qashqadaryo
# 6                            Xorazm
# 7                          Namangan
# 8                           Andijon
# 9                            Jizzax
# 10                         Sirdaryo
# 11                           Navoiy
# 12    Qoraqalpog'iston Respublikasi
# dtype: object

# %%
#@title **To'g'ri javob**
obj = pd.Series(
    [
        "Andijon",
        "Buxoro",
        "Farg'ona",
        "Jizzax",
        "Xorazm",
        "Namangan",
        "Navoiy",
        "Qashqadaryo",
        "Qoraqalpog'iston Respublikasi",
        "Samarqand",
        "Sirdaryo",
        "Surxondaryo",
        "Toshkent",
    ]
)
print(obj)
# Out:
# 0                           Andijon
# 1                            Buxoro
# 2                          Farg'ona
# 3                            Jizzax
# 4                            Xorazm
# 5                          Namangan
# 6                            Navoiy
# 7                       Qashqadaryo
# 8     Qoraqalpog'iston Respublikasi
# 9                         Samarqand
# 10                         Sirdaryo
# 11                      Surxondaryo
# 12                         Toshkent
# dtype: object

# %% [markdown]
# ### **3-mashq.** Yuqorida yaratilgan Series obyektining barcha qiymaltarini chiqaring

# %%
# Javobni shuyerga yozing
obj1.values
# Out:
# array(['Fargʻona', 'Toshkent', 'Samarqand', 'Buxoro', 'Surxondaryo',
#        'Qashqadaryo', 'Xorazm', 'Namangan', 'Andijon', 'Jizzax',
#        'Sirdaryo', 'Navoiy', "Qoraqalpog'iston Respublikasi"],
#       dtype=object)

# %%
# @title **To'g'ri javob**
obj.values
# Out:
# array(['Andijon', 'Buxoro', "Farg'ona", 'Jizzax', 'Xorazm', 'Namangan',
#        'Navoiy', 'Qashqadaryo', "Qoraqalpog'iston Respublikasi",
#        'Samarqand', 'Sirdaryo', 'Surxondaryo', 'Toshkent'], dtype=object)

# %% [markdown]
# ### **4-mashq.** Yuqoridagi Series obyektining eng birinchi qiymatini chiqaring

# %%
# Javobni shuyerga yozing
obj1[0]
# Out:
# 'Fargʻona'

# %%
# @title **To'g'ri javob**
obj[0]
# Out:
# 'Andijon'

# %% [markdown]
# ### **5-mashq.** Yuqoridagi Series obyektining eng oxirgi qiymatini chiqaring

# %%
# Javobni shuyerga yozing
obj1.iloc[-1]
# Out:
# "Qoraqalpog'iston Respublikasi"

# %%
obj1[12]
# Out:
# "Qoraqalpog'iston Respublikasi"

# %%
# @title **To'g'ri javob**
obj[12]
# Out:
# 'Toshkent'

# %% [markdown]
# ### **6-mashq.** Yuqoridagi Series obyekti uzunligini chiqaring

# %%
# Javobni shuyerga yozing
len(obj1)
obj1.size
# Out:
# 13

# %%
# @title **To'g'ri javob**
obj.size
# Out:
# 13

# %% [markdown]
# ### **7-mashq.** Yuqoridagi Series obyektining o'rtasidan 3 ta qiymat chiqaring

# %%
# Javobni shuyerga yozing
obj1[5:8]
# Out:
# 5    Qashqadaryo
# 6         Xorazm
# 7       Namangan
# dtype: object

# %%
obj1[[5,6,7]]
# Out:
# 5    Qashqadaryo
# 6         Xorazm
# 7       Namangan
# dtype: object

# %%
# @title **To'g'ri javob**

obj[[5, 6, 7]]
# Out:
# 5       Namangan
# 6         Navoiy
# 7    Qashqadaryo
# dtype: object

# %% [markdown]
# ### **8-mashq.** Quyidagi Series obyektini yarating.
# **Ahamiyat bering. `Series` obyekti indeksi sifatida viloyatlar nomi ishlatilgan**

# %%
# @title
ind = obj.values
aholi = [
    1899000,
    1384700,
    2597000,
    910500,
    1200000,
    1862000,
    767500,
    2029000,
    1200000,
    2322000,
    648100,
    1676000,
    4450000,
]
obj2 = pd.Series(aholi, index=ind)
print(obj2)
# Out:
# Andijon                          1899000
# Buxoro                           1384700
# Farg'ona                         2597000
# Jizzax                            910500
# Xorazm                           1200000
# Namangan                         1862000
# Navoiy                            767500
# Qashqadaryo                      2029000
# Qoraqalpog'iston Respublikasi    1200000
# Samarqand                        2322000
# Sirdaryo                          648100
# Surxondaryo                      1676000
# Toshkent                         4450000
# dtype: int64

# %%
# Javobni shuyerga yozing
obj2 = pd.Series([1899000, 1384700, 2597000, 910500, 1200000, 1862000, 767500,
                  2029000, 1200000, 2322000, 648100, 1676000, 4450000], index = regions)
print(obj2)
# Out:
# Fargʻona                         1899000
# Toshkent                         1384700
# Samarqand                        2597000
# Buxoro                            910500
# Surxondaryo                      1200000
# Qashqadaryo                      1862000
# Xorazm                            767500
# Namangan                         2029000
# Andijon                          1200000
# Jizzax                           2322000
# Sirdaryo                          648100
# Navoiy                           1676000
# Qoraqalpog'iston Respublikasi    4450000
# dtype: int64

# %% [markdown]
# ### **9-mashq.** Yuqoridagi `Series` obyektidan Jizzax, Buxoro va Namangan viloyatlarining aholisini chiqaring

# %%
# Javobni shuyerga yozing

obj2[['Jizzax','Buxoro','Namangan']]
# Out:
# Jizzax      2322000
# Buxoro       910500
# Namangan    2029000
# dtype: int64

# %%
# @title **To'g'ri javob**
obj2[["Jizzax", "Buxoro", "Namangan"]]
# Out:
# Jizzax      2322000
# Buxoro       910500
# Namangan    2029000
# dtype: int64

# %% [markdown]
# ### **10-mashq.** Yuqoridagi `Series` obyektidan aholi soni 1 milliondan kam va ko'p bo'lgan viloyatlarni alohida chiqaring

# %%
# Javobni shuyerga yozing
kop = obj2[obj2>1000000]
kop.index.name = "Aholisi 1 milliondan ko'p viloyatlar"
print(kop)
# Out:
# Aholisi 1 milliondan ko'p viloyatlar
# Fargʻona                         1899000
# Toshkent                         1384700
# Samarqand                        2597000
# Surxondaryo                      1200000
# Qashqadaryo                      1862000
# Namangan                         2029000
# Andijon                          1200000
# Jizzax                           2322000
# Navoiy                           1676000
# Qoraqalpog'iston Respublikasi    4450000
# dtype: int64

# %%
kam = obj2[obj2<1000000]
kam.index.name = "Aholisi 1 milliondan kam viloyatlar"
print(kam)
# Out:
# Aholisi 1 milliondan kam viloyatlar
# Buxoro      910500
# Xorazm      767500
# Sirdaryo    648100
# dtype: int64

# %%
# @title **To'g'ri javob**
print("Aholisi 1 milliondan ko'p viloyatlar")
print(obj2[obj2 > 1_000_000])
# Pythonda katta sonlarni yozishda 0 orasini _ bilan ajratish mumkin
# Out:
# Aholisi 1 milliondan ko'p viloyatlar
# Fargʻona                         1899000
# Toshkent                         1384700
# Samarqand                        2597000
# Surxondaryo                      1200000
# Qashqadaryo                      1862000
# Namangan                         2029000
# Andijon                          1200000
# Jizzax                           2322000
# Navoiy                           1676000
# Qoraqalpog'iston Respublikasi    4450000
# dtype: int64

# %%
# @title
print("Aholisi 1 milliondan kam viloyatlar")
print(obj2[obj2 < 1_000_000])
# Out:
# Aholisi 1 milliondan kam viloyatlar
# Buxoro      910500
# Xorazm      767500
# Sirdaryo    648100
# dtype: int64

# %% [markdown]
# ### **11-mashq.** Aholisi 1 milliondan ko'p davlatlar orasida Navoiy viloyati bor/yo'qligini tekshiring

# %%
# Javobni shuyerga yozing
"Navoiy" in obj2[obj2>1_000_000]
# Out:
# True

# %%
# @title **To'g'ri javob**
"Navoiy" in obj2[obj2 > 1_000_000]
# Out:
# True

# %% [markdown]
# ### **12-mashq.** Quyidagi lug'atda viloyatlar va ularning maydonlari berilgan. Lug'atdan yangi `Series` obyektini yarating va unga "Hududlar hajmi" deb nom bering

# %%
dictionary = {
    "Andijon": 4200,
    "Buxoro": 39400,
    "Farg'ona": 6800,
    "Jizzax": 20500,
    "Xorazm": 6300,
    "Namangan": 7900,
    "Navoiy": 110800,
    "Qashqadaryo": 28400,
    "Qoraqalpog'iston Respublikasi": 160000,
    "Samarqand": 16400,
    "Sirdaryo": 5100,
    "Surxondaryo": 20800,
    "Toshkent": 15300,
}

# %%
# Javobni shuyerga yozing
obj3 = pd.Series(dictionary)
obj3.name = 'Hududlar hajmi'
print(obj3)
# Out:
# Andijon                            4200
# Buxoro                            39400
# Farg'ona                           6800
# Jizzax                            20500
# Xorazm                             6300
# Namangan                           7900
# Navoiy                           110800
# Qashqadaryo                       28400
# Qoraqalpog'iston Respublikasi    160000
# Samarqand                         16400
# Sirdaryo                           5100
# Surxondaryo                       20800
# Toshkent                          15300
# Name: Hududlar hajmi, dtype: int64

# %%
#@title To'g'ri javob
obj3 = pd.Series(dict)
obj3.name = "Hudular hajmi"
print(obj3)
# Out:
# Andijon                            4200
# Buxoro                            39400
# Farg'ona                           6800
# Jizzax                            20500
# Xorazm                             6300
# Namangan                           7900
# Navoiy                           110800
# Qashqadaryo                       28400
# Qoraqalpog'iston Respublikasi    160000
# Samarqand                         16400
# Sirdaryo                           5100
# Surxondaryo                       20800
# Toshkent                          15300
# Name: Hudular hajmi, dtype: int64

# %% [markdown]
# ### **13-mashq.** Yuqoridagi `Series` obyektidan hududi eng katta va eng kichik elementlarni chiqaring

# %%
# Javobni shuyerga yozing
a, b = obj3.argmax(), obj3.argmin()
print('Eng katta hudud:', obj3.index[a] )
print('Eng kichik hudud:', obj3.index[b])
# Out:
# Eng katta hudud: Qoraqalpog'iston Respublikasi
# Eng kichik hudud: Andijon

# %%
print(f"Eng katta hudud: {obj3.idxmax()}")
print(f"Eng kichik hudud: {obj3.idxmin()}")
# Out:
# Eng katta hudud: Qoraqalpog'iston Respublikasi
# Eng kichik hudud: Andijon

# %%
#@title To'g'ri javob
print(f"Eng katta hudud: {obj3.idxmax()}")
print(f"Eng kichik hudud: {obj3.idxmin()}")
# Out:
# Eng katta hudud: Qoraqalpog'iston Respublikasi
# Eng kichik hudud: Andijon

# %%
obj2
# Out:
# Fargʻona                         1899000
# Toshkent                         1384700
# Samarqand                        2597000
# Buxoro                            910500
# Surxondaryo                      1200000
# Qashqadaryo                      1862000
# Xorazm                            767500
# Namangan                         2029000
# Andijon                          1200000
# Jizzax                           2322000
# Sirdaryo                          648100
# Navoiy                           1676000
# Qoraqalpog'iston Respublikasi    4450000
# dtype: int64

# %% [markdown]
# ### **14-mashq.** Yuqoridagi eng katta va eng kichik hududlar aholisi sonini chiqaring

# %%
# Javobni shuyerga yozing
print(f"{obj3.idxmax()} aholisi {obj2[obj3.idxmax()]}")
print(f"{obj3.idxmin()} aholisi {obj2[obj3.idxmin()]}")
# Out:
# Qoraqalpog'iston Respublikasi aholisi 4450000
# Andijon aholisi 1200000

# %%
#@title To'g'ri javob
print(f"{obj3.idxmax()} aholisi {obj2[obj3.idxmax()]}")
print(f"{obj3.idxmin()} aholisi {obj2[obj3.idxmin()]}")
# Out:
# Qoraqalpog'iston Respublikasi aholisi 4450000
# Andijon aholisi 1200000

# %% [markdown]
# ### **15-mashq**. Yuqoridagi hudulardan O'zbekiston Respublikasi hududini hisoblang

# %%
# Javobni shuyerga yozing
uz_hudud = obj3.sum()
uz_hudud
# Out:
# np.int64(441900)

# %%
#@title To'g'ri javob
sum(obj3)
# Out:
# 441900

# %% [markdown]
# ### **16-mashq.** Aholisi eng ko'p va eng kam hududlarning hajmini va aholi sonini chiqaring

# %%
# Javobni shuyerga yozing
print(f"{obj2.idxmax()} hududi {obj3[obj2.idxmax()]}kv.km, aholisi {obj2.max()}")
print(f"{obj2.idxmin()} hududi {obj3[obj2.idxmin()]}kv.km, aholisi {obj2.min()}")
# Out:
# Qoraqalpog'iston Respublikasi hududi 160000kv.km, aholisi 4450000
# Sirdaryo hududi 5100kv.km, aholisi 648100

# %%
#@title To'g'ri javob
print(f"{obj2.idxmax()} hududi {obj3[obj2.idxmax()]}kv.km, aholisi {obj2[obj2.idxmax()]}")
print(f"{obj2.idxmin()} hududi {obj3[obj2.idxmin()]}kv.km, aholisi {obj2[obj2.idxmin()]}")
# Out:
# Qoraqalpog'iston Respublikasi hududi 160000kv.km, aholisi 4450000
# Sirdaryo hududi 5100kv.km, aholisi 648100

# %% [markdown]
# ### **17-mashq.** Yuqoridagi ikki obyektdan foydalangan holda O'zbekiston respublikasi tarkibidagi hududlarni avval aholi soni bo'yicha, keyin esa hajmi bo'yicha tartiblab chiqaring

# %%
# Javobni shuyerga yozing
print("Hududlar hajmi bo'yicha tartiblash")
obj3.sort_values()
# Out:
# Hududlar hajmi bo'yicha tartiblash
# Andijon                            4200
# Sirdaryo                           5100
# Xorazm                             6300
# Farg'ona                           6800
# Namangan                           7900
# Toshkent                          15300
# Samarqand                         16400
# Jizzax                            20500
# Surxondaryo                       20800
# Qashqadaryo                       28400
# Buxoro                            39400
# Navoiy                           110800
# Qoraqalpog'iston Respublikasi    160000
# Name: Hudular hajmi, dtype: int64

# %%
#@title To'g'ri javob
print("Hududlar hajmi bo'yicha tartiblash")
obj3.sort_values()
# Out:
# Hududlar hajmi bo'yicha tartiblash
# Andijon                            4200
# Sirdaryo                           5100
# Xorazm                             6300
# Farg'ona                           6800
# Namangan                           7900
# Toshkent                          15300
# Samarqand                         16400
# Jizzax                            20500
# Surxondaryo                       20800
# Qashqadaryo                       28400
# Buxoro                            39400
# Navoiy                           110800
# Qoraqalpog'iston Respublikasi    160000
# Name: Hudular hajmi, dtype: int64

# %%
print("Aholi soni bo'yicha tartiblash")
obj2.sort_values()
# Out:
# Aholi soni bo'yicha tartiblash
# Sirdaryo                          648100
# Xorazm                            767500
# Buxoro                            910500
# Surxondaryo                      1200000
# Andijon                          1200000
# Toshkent                         1384700
# Navoiy                           1676000
# Qashqadaryo                      1862000
# Fargʻona                         1899000
# Namangan                         2029000
# Jizzax                           2322000
# Samarqand                        2597000
# Qoraqalpog'iston Respublikasi    4450000
# dtype: int64

# %%
#@title To'g'ri javob
print("Aholi soni bo'yicha tartiblash")
obj2.sort_values()
# Out:
# Aholi soni bo'yicha tartiblash
# Sirdaryo                          648100
# Xorazm                            767500
# Buxoro                            910500
# Surxondaryo                      1200000
# Andijon                          1200000
# Toshkent                         1384700
# Navoiy                           1676000
# Qashqadaryo                      1862000
# Fargʻona                         1899000
# Namangan                         2029000
# Jizzax                           2322000
# Samarqand                        2597000
# Qoraqalpog'iston Respublikasi    4450000
# dtype: int64
